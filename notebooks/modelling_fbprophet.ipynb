# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from fbprophet import Prophet

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.3

# %%
# pip install fbprophet

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean((np.abs(y_pred - y_true)/ y_pred))*100

# %%
df_all = pd.read_csv('../data/processed/COVID_small_table_confirmed.csv',sep=';')
df=df_all[['date','Germany']]
df=df.rename(columns={'date': 'ds',
                        'Germany': 'y'})

# %%
ax = df.set_index('ds').plot(figsize=(12, 8), logy= True)
ax.set_ylabel('Daily Number of confimed cases')
ax.set_xlabel('Date')

plt.show()
